# %% [markdown]
# # Import Functions and Data

# %%
import functions_paper_1
import importlib
from functions_paper_1 import *
exec(open("functions_paper_1.py").read())

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from pathlib import Path
# from scipy import stats
# from statannotations.Annotator import Annotator
# import rushd as rd


datadir = Path(Path('../../datadir_amb.txt').read_text())
datadir = Path(Path('../../datadir_srk.txt').read_text())
figure_folder = './figs_2024_promoter_editing_paper/MEFS_TET-ZF/'

# %%
font_sizes = {
    'annotation': 4,
    'base_size': 6,
    'subpanel_label': 10,
}

sns.set_style('ticks')
sns.set_context('paper', font_scale=1.0, rc={'font.size': font_sizes['base_size'], 'font.family': 'sans-serif', 'font.sans-serif':['Helvetica Neue']})
plt.rcParams.update({'axes.labelsize': font_sizes['base_size'], 'xtick.labelsize': font_sizes['base_size'], 'ytick.labelsize': font_sizes['base_size']})

# %%
sns.set_context('talk')

# %%
data_loc1 = datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep1' /  'single_cell_csvs'
yaml_loc1 =  datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep1' / 'metadata.yaml'
data_loc2 = datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep2' /  'single_cell_csvs'
yaml_loc2 =  datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep2' / 'metadata.yaml'
data_loc3 = datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep3' /  'single_cell_csvs'
yaml_loc3 =  datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep3' / 'metadata.yaml'

file_paths = [data_loc1, data_loc2, data_loc3]
yaml_paths =[yaml_loc1, yaml_loc2, yaml_loc3]

for i in [0,1,2]:
    file_path = file_paths[i]
    yaml_path =yaml_paths[i]
    data_now = rd.flow.load_csv_with_metadata(file_path, yaml_path)
    if i == 0:
        data = data_now
    else:
        data = pd.concat([data_now, data])


# groups_df = pd.DataFrame(data = {'data_path': [data_loc1, data_loc2, data_loc3], 'yaml_path':[yaml_loc1, yaml_loc2, yaml_loc3]})

# data = rd.flow.load_groups_with_metadata(groups_df, columns = ['BL1-A', 'RL1-A', 'YL2-A', 'VL1-A'])
data
# Out:
#             condition         promoter marker   ZFa ZF_delivery    Dox    Cre  \
# 0       mGreenLantern  divergent_203bp   iRFP  ZF37       retro  False  False
# 1       mGreenLantern  divergent_203bp   iRFP  ZF37       retro  False  False
# 2       mGreenLantern  divergent_203bp   iRFP  ZF37       retro  False  False
# 3       mGreenLantern  divergent_203bp   iRFP  ZF37       retro  False  False
# 4       mGreenLantern  divergent_203bp   iRFP  ZF37       retro  False  False
# ...               ...              ...    ...   ...         ...    ...    ...
# 619533       Halo-lig             none   none  none        none  False  False
# 619534       Halo-lig             none   none  none        none  False  False
# 619535       Halo-lig             none   none  none        none  False  False
# 619536       Halo-lig             none   none  none        none  False  False
# 619537       Halo-lig             none   none  none        none  False  False
#
#         BioRep  CellTraceViolet well  ...  VL1-A  VL1-H  VL1-W  YL1-A  YL1-H  \
# 0            3             True  A10  ...  33991  22085     95    157    100
# 1            3             True  A10  ...   3966   3107     39    -67     25
# 2            3             True  A10  ...  44342  21086    144    207    137
# 3            3             True  A10  ...  13020   9223     62    -52     53
# 4            3             True  A10  ...  21647  15254     73     57     50
# ...        ...              ...  ...  ...    ...    ...    ...    ...    ...
# 619533       1            False   H8  ...     16    117      0     28     78
# 619534       1            False   H8  ...     16     81      0    -61     30
# 619535       1            False   H8  ...    -91    167      0    -53     52
# 619536       1            False   H8  ...     56     54      0    107     73
# 619537       1            False   H8  ...    225    105      0    -69     62
#
#         YL1-W  YL2-A  YL2-H  YL2-W       Time
# 0           0   1116    710      0   0.002040
# 1           0     86    102      0   0.009178
# 2           0   1745    923      0   0.024476
# 3           0     82    150      0   0.031614
# 4           0    471    383      0   0.041813
# ...       ...    ...    ...    ...        ...
# 619533      0     54     62      0  22.977600
# 619534      0     40     48      0  22.980600
# 619535      0     19     59      0  22.985700
# 619536      0    113    120      0  22.991800
# 619537      0    -67     56      0  23.003100
#
# [2302146 rows x 33 columns]

# %% [markdown]
# # Histograms

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['loxPcon', 'divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['retro']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin(['modRNA'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
subdata = subdata.reset_index(drop=True)
display(subdata)

fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'VL1-A', y = 'YL2-A', hue = 'promoter', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)
axs.set(xlim = (10, 10**5), ylim = (1, 10**3))
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))
# Out:
#            condition         promoter marker   ZFa ZF_delivery    Dox     Cre  \
# 0      mGreenLantern          loxPcon   iRFP  ZF43       retro  False  modRNA
# 1      mGreenLantern          loxPcon   iRFP  ZF43       retro  False  modRNA
# 2      mGreenLantern          loxPcon   iRFP  ZF43       retro  False  modRNA
# 3      mGreenLantern          loxPcon   iRFP  ZF43       retro  False  modRNA
# 4      mGreenLantern          loxPcon   iRFP  ZF43       retro  False  modRNA
# ...              ...              ...    ...   ...         ...    ...     ...
# 57526  mGreenLantern  divergent_203bp   iRFP  ZF43       retro  False  modRNA
# 57527  mGreenLantern  divergent_203bp   iRFP  ZF43       retro  False  modRNA
# 57528  mGreenLantern  divergent_203bp   iRFP  ZF43       retro  False  modRNA
# 57529  mGreenLantern  divergent_203bp   iRFP  ZF43       retro  False  modRNA
# 57530  mGreenLantern  divergent_203bp   iRFP  ZF43       retro  False  modRNA
#
#        BioRep  CellTraceViolet well  ... VL1-A  VL1-H  VL1-W  YL1-A  YL1-H  \
# 0           3            False   B1  ...   144    108      0    116    103
# 1           3            False   B1  ...   455    478      0    -96     31
# 2           3            False   B1  ...   121    111      0     47     53
# 3           3            False   B1  ...  1271    857      0      4     89
# 4           3            False   B1  ...   412    140      0     54     66
# ...       ...              ...  ...  ...   ...    ...    ...    ...    ...
# 57526       1            False   E3  ...   406    216      0     64     77
# 57527       1            False   E3  ...  2481   1144     30     61     59
# 57528       1            False   E3  ...  1298    730      0   -107     41
# 57529       1            False   E3  ...  1113    752      0    -92     48
# 57530       1            False   E3  ...     2    122      0    -80     33
#
#        YL1-W  YL2-A  YL2-H  YL2-W       Time
# 0          0     63     75      0   0.043269
# 1          0    138    156      0   0.067419
# 2          0    161     92      0   0.088551
# 3          0    377    208      0   0.101632
# 4          0    242     88      0   0.106663
# ...      ...    ...    ...    ...        ...
# 57526      0     73     94      0  22.974800
# 57527      0    231    126      0  22.980900
# 57528      0    198    108      0  22.987900
# 57529      0    181    107      0  22.994000
# 57530      0     19     84      0  23.011100
#
# [57531 rows x 33 columns]

# %%
ZF43_retro_gate = 10**3

axs.vlines(x = ZF43_retro_gate, ymin = 1, ymax = 5*10**3, color = 'black', lw = 3)
fig.set_facecolor('white')
fig

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['retro']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False,'modRNA', 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > ZF43_retro_gate) &
               (data['YL2-A'] > 0)  ]
subdata = subdata.reset_index(drop=True)
fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

# %%
axs.set(xlim = (10, 10**6), ylim = (10, 5*10**5))
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

iRFP_gate = 4*10**3

axs.vlines(x = iRFP_gate, ymin = 1, ymax = 5*10**5, color = 'black', lw = 3)
fig.set_facecolor('white')
fig

# %%
iRFP_gate = 4*10**3
ZF43_retro_gate = 3*10**3

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['retro']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False,'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > ZF43_retro_gate) &
               (data['YL2-A'] > 0)  ]
subdata = subdata.reset_index(drop=True)
fig, axs = plt.subplots(1, 1, figsize = (6, 6))
subdata = subdata.reset_index(drop=True)
sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5))
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')
fig

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['loxPcon']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['retro']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False,'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > ZF43_retro_gate) &
               (data['YL2-A'] > 0)  ]
subdata = subdata.reset_index(drop=True)
fig, axs = plt.subplots(1, 1, figsize = (6, 6))
subdata = subdata.reset_index(drop=True)
sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5))
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False, True]) ) &
               (data.Cre.isin([False])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
subdata = subdata.reset_index(drop=True)
fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Dox', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False, True]) ) &
               (data.Cre.isin(['retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
subdata = subdata.reset_index(drop=True)
colors = {False:'grey', True:'C3DB9A'}

fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Dox', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
cmap_no_cre = sns.light_palette('#C3DB9A', as_cmap=True)

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ].sample(5000)

subdata = subdata.reset_index(drop=True)
fig, axs = plt.subplots(1, 1, figsize = (1, 1))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', linewidths = 1, levels = 4)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression')

subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ].sample(5000)


sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', common_norm = False, log_scale=True, ax  =axs,  fill = True, cmap = cmap_no_cre )


fig.set_facecolor('white')
fig.savefig(figure_folder + "lenti_ZF_MEFs_dox_2D.svg", bbox_inches = 'tight')

# %%
fig.savefig(figure_folder + "lenti_ZF_MEFs_dox_2D.svg", bbox_inches = 'tight')

# %%
subdata = CTV_data[(CTV_data.condition.isin(['Halo-p53'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['mGreenLantern']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]
subdata.well.value_counts()

fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'RL1-A',  hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel ='Halo-p53\n[output gene expression]', xlim = (5, 3*10**4))
# axs.set(xlim = (), ylim = (), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')


halo_lig_data = data[(data.condition.isin(['Halo-lig'])) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]

sns.kdeplot(data = halo_lig_data, x = 'RL1-A', common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', legend = False, ls = '--')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False, True]) ) &
               (data.Cre.isin(['retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > ZF43_retro_gate) &
               (data['YL2-A'] > 0)  ]


fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Dox', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]

colors = {False: '#C3DB9A', 'retro': '#69B645'}


fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5, palette = colors)

axs.set(xlim = (10, 5*10**5), xlabel = 'Output [mGL]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

no_dox = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]

sns.kdeplot(data = no_dox, x = 'BL1-A', color = 'black', ls = '--', log_scale = True, common_norm = False, fill = False, ax = axs, legend = False)

fig.set_facecolor('white')

# %%
xsize = 4
ysize = 1.8
fontsize = 16.5


data_now = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]

data_neg = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]


data_now = pd.concat([data_now, data_neg], ignore_index = True)

parameters = pd.array(['BL1-A'])
hue = 'Cre'
hue_order = None
xlim = [10, 5*10**5]
plottitle = 'test'
parameters = pd.array(['BL1-A'])
hue = 'total_cond'
hue_order = None
xlim = [10, 5*10**5]
plottitle = 'test'


palette = {'False-False':'grey', 'False-retro':'black', 'True-False':'#C3DB9A', 'True-retro':'#69B645'}

g = plt.figure(figsize=[xsize,ysize])
g = custom_hist_plot( data_now, parameters, hue=hue, palette=palette, hueorder=hue_order, xsize=xsize, ysize=ysize, title=plottitle, 
                         alpha=0.1,fontsize=fontsize, 
                         legendtitle='Condition', xlim=xlim)
g.set(xlabel = 'Output (mGL)')
g = g.get_figure()
g.savefig(figure_folder + "lenti_ZF_MEFs_dox.svg", bbox_inches = 'tight')

# %%
data['total_cond'] = data['Dox'].astype('str') + '-' + data['Cre'].astype('str')

# %%
xsize = 4
ysize = 1.8
fontsize = 16.5


data_now = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > ZF43_retro_gate) &
               (data['YL2-A'] > 0)  ]

data_neg = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]


data_now = pd.concat([data_now, data_neg], ignore_index = True)

parameters = pd.array(['BL1-A'])
hue = 'total_cond'
hue_order = None
xlim = [10, 5*10**5]
plottitle = 'test'


palette = {'False-False':'grey', 'False-retro':'black', 'True-False':'#C3DB9A', 'True-retro':'#69B645'}

g = plt.figure(figsize=[xsize,ysize])
g = custom_hist_plot( data_now, parameters, hue=hue, palette=palette, hueorder=hue_order, xsize=xsize, ysize=ysize, title=plottitle, 
                         alpha=0.1,fontsize=fontsize, 
                         legendtitle='Condition', xlim=xlim)
g.set(xlabel = 'Output (mGL)')
g = g.get_figure()
g.savefig(figure_folder + "lenti_ZF_MEFs_cre.svg", bbox_inches = 'tight')

# %% [markdown]
# # Calculate Stats

# %% [markdown]
# ## Summary Stats

# %%
#iRFP670 gated no dox condition
iRFP_gate = 4*10**3
ZF43_retro_gate = 10**3
data_gate = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
df = data_gate #choose dataframe
#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
by = ['condition', 'promoter', 'marker', 'ZFa', 'ZF_delivery', 'Dox', 'Cre', 'BioRep'] #how to filter results, columns 
x = ['BL1-A'] #which parameter to calculate results on
stat = [sp.stats.gmean, np.median, np.std, np.mean] #statistics to calculate
s_well_iRFPgated = calc_stats(df,by,x,stat) #calculate statistics 

#iRFP670 gated, ZF43 gated with dox conditions
data_gate = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > ZF43_retro_gate) &
               (data['YL2-A'] > 0)   ]
df = data_gate #choose dataframe
#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
by = ['condition', 'promoter', 'marker', 'ZFa', 'ZF_delivery', 'Dox', 'Cre', 'BioRep'] #how to filter results, columns 
x = ['BL1-A'] #which parameter to calculate results on
stat = [sp.stats.gmean, np.median, np.std, np.mean] #statistics to calculate
s_well_iRFPgated_ZF_gated = calc_stats(df,by,x,stat) #calculate statistics 


summary_well = pd.concat([s_well_iRFPgated, s_well_iRFPgated_ZF_gated], ignore_index=True)
summary_well['total_cond'] = summary_well['Dox'].astype('str') + '-' + summary_well['Cre'].astype('str')
summary_well
#summary_well.to_excel('Fig5_MEFs_TET-ZF_gated.xlsx',index=False)
# Out:
#         condition         promoter marker   ZFa ZF_delivery    Dox    Cre  \
# 0   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 1   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 2   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 3   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 4   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 5   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 6   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 7   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 8   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 9   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 10  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 11  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
#
#     BioRep  BL1-A_gmean  BL1-A_median     BL1-A_std    BL1-A_mean  Fraction  \
# 0        1   110.586569         129.0    586.253422    179.477660  0.295997
# 1        2   103.052234         122.0    779.775405    178.570464  0.430033
# 2        3   107.268205         126.0    903.160046    179.274297  0.273970
# 3        1   110.688558         125.0    926.114146    208.023042  0.344166
# 4        2   103.742943         122.0    884.929931    184.381585  0.392691
# 5        3   105.175445         123.0    552.079736    168.900105  0.263143
# 6        1   931.758367         832.0   3724.066624   2034.750321  0.368458
# 7        2   960.623990         960.0   3209.703329   2052.924796  0.392020
# 8        3   797.247347         686.0   2823.935515   1704.264953  0.239522
# 9        1  3067.354679        3784.0  17882.454214  10026.234654  0.407666
# 10       2  4188.428307        5384.0  17400.309185  12039.605239  0.338613
# 11       3  3843.751445        5262.0  16247.742349  11576.425718  0.253722
#
#     Count   total_cond
# 0   13451  False-False
# 1   19542  False-False
# 2   12450  False-False
# 3    6206  False-retro
# 4    7081  False-retro
# 5    4745  False-retro
# 6    3112   True-False
# 7    3311   True-False
# 8    2023   True-False
# 9    1287   True-retro
# 10   1069   True-retro
# 11    801   True-retro

# %% [markdown]
# ## Fold Change Calculation

# %%
fold_change_map = {'bio':'noCre'}
for biorep in [1,2,3]:
    data_noCre = summary_well[(summary_well['BioRep']== biorep) & (summary_well['total_cond']=='True-False')]
    fold_change_map[biorep] = data_noCre['BL1-A_gmean'].iloc[0]
summary_well['Fold Change'] = summary_well['BL1-A_gmean'] / summary_well['BioRep'].map(fold_change_map) 
display(summary_well)

#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
df = summary_well
by = ['Dox', 'Cre'] #how to filter results, columns 
x = ['BL1-A_gmean','Fold Change'] #which parameter to calculate results on
stat = [np.mean] #statistics to calculate
summary_well_means = calc_stats(df,by,x,stat) #calculate statistics 
display(summary_well_means)
# Out:
#         condition         promoter marker   ZFa ZF_delivery    Dox    Cre  \
# 0   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 1   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 2   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 3   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 4   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 5   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 6   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 7   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 8   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  False
# 9   mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 10  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 11  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 12  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 13  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 14  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 15  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 16  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 17  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti  False  retro
# 18  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 19  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 20  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 21  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 22  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 23  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 24  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 25  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 26  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  False
# 27  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 28  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 29  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 30  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 31  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 32  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 33  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 34  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
# 35  mGreenLantern  divergent_203bp   iRFP  ZF43       lenti   True  retro
#
#     BioRep well  BL1-A_gmean  BL1-A_median     BL1-A_std    BL1-A_mean  \
# 0        1   D4   109.495222         126.0    480.075117    171.030103
# 1        1   D5   110.087929         130.0    513.985609    174.934732
# 2        1   D6   112.331420         132.0    741.660019    193.502204
# 3        2   D4   105.516503         124.0    877.027942    189.215327
# 4        2   D5   104.344122         124.0    681.391345    175.268200
# 5        2   D6    99.932905         119.0    786.579135    173.307150
# 6        3   D4   107.981397         128.0    828.472023    175.057001
# 7        3   D5   106.449767         125.0    549.326894    164.406728
# 8        3   D6   107.582393         124.0   1207.811257    198.256148
# 9        1   F4   112.241871         126.0    952.885822    218.830009
# 10       1   F5   110.827176         125.0   1084.730760    232.216100
# 11       1   F6   108.945033         125.0    687.875248    171.634377
# 12       2   F4   101.754135         119.0    808.984497    188.065702
# 13       2   F5   104.389660         124.0   1196.623171    192.300762
# 14       2   F6   105.160484         122.0    562.155574    173.441975
# 15       3   F4   103.389347         121.0    402.332604    155.077153
# 16       3   F5   106.002898         126.0    792.315779    193.795389
# 17       3   F6   106.289909         125.0    424.515647    162.109199
# 18       1   D7   954.889702         867.0   4220.921100   2135.817483
# 19       1   D8   981.138954         920.5   3801.553290   2124.892708
# 20       1   D9   870.853999         711.0   3105.619188   1862.160216
# 21       2   D7   916.855160         896.0   3145.182636   1989.351986
# 22       2   D8  1033.575478        1071.0   3412.664955   2212.750218
# 23       2   D9   931.881018         939.5   3041.899504   1946.534026
# 24       3   D7   826.593887         748.5   2997.392369   1795.296552
# 25       3   D8   793.325452         706.0   2690.708914   1664.123410
# 26       3   D9   739.544074         599.0   2675.154231   1574.438692
# 27       1   F7  3033.410104        3759.0  15832.751972   9914.415094
# 28       1   F8  2965.091420        3860.5  17855.833552   9602.602439
# 29       1   F9  3218.260886        3765.5  20106.725553  10593.802500
# 30       2   F7  3619.066706        4302.0  18902.435952  11487.933754
# 31       2   F8  4558.795665        6874.5  15214.069997  12036.269444
# 32       2   F9  4360.838647        5391.0  18035.142874  12488.790816
# 33       3   F7  4076.413317        5515.5  17361.120157  12354.433566
# 34       3   F8  3704.767417        5091.5  16919.818783  11948.851852
# 35       3   F9  3737.555271        4799.0  13973.617372  10257.791837
#
#     Fraction  Count   total_cond Fold Change
# 0   0.360568   4850  False-False    0.114668
# 1   0.318935   4290  False-False    0.115289
# 2   0.320497   4311  False-False    0.117638
# 3   0.287790   5624  False-False    0.115085
# 4   0.349350   6827  False-False    0.113807
# 5   0.362859   7091  False-False    0.108995
# 6   0.274779   3421  False-False    0.130634
# 7   0.372450   4637  False-False    0.128781
# 8   0.352771   4392  False-False    0.130151
# 9   0.339349   2106  False-retro    0.117544
# 10  0.336287   2087  False-retro    0.116063
# 11  0.324364   2013  False-retro    0.114092
# 12  0.341760   2420  False-retro    0.110982
# 13  0.315068   2231  False-retro    0.113856
# 14  0.343172   2430  False-retro    0.114697
# 15  0.352371   1672  False-retro    0.125079
# 16  0.292518   1388  False-retro    0.128241
# 17  0.355111   1685  False-retro    0.128588
# 18  0.334512   1041   True-False         1.0
# 19  0.308483    960   True-False    1.027489
# 20  0.357005   1111   True-False    0.911994
# 21  0.334642   1108   True-False         1.0
# 22  0.345817   1145   True-False    1.127305
# 23  0.319541   1058   True-False    1.016388
# 24  0.430054    870   True-False         1.0
# 25  0.388532    786   True-False    0.959752
# 26  0.181414    367   True-False    0.894689
# 27  0.370629    477   True-retro    3.176713
# 28  0.318570    410   True-retro    3.105166
# 29  0.310800    400   True-retro    3.370296
# 30  0.296539    317   True-retro    3.947261
# 31  0.336763    360   True-retro    4.972209
# 32  0.366698    392   True-retro      4.7563
# 33  0.357054    286   True-retro    4.931579
# 34  0.337079    270   True-retro    4.481968
# 35  0.305868    245   True-retro    4.521634
#      Dox    Cre  BL1-A_gmean_mean  Fold Change_mean  Fraction  Count
# 0  False  False        107.080184          0.119450       0.5      9
# 1  False  retro        106.555612          0.118793       0.5      9
# 2   True  False        894.295303          0.993069       0.5      9
# 3   True  retro       3697.133270          4.140347       0.5      9

# %% [markdown]
# ## Summary Plots

# %%
xsize =2; ysize = 1.5
fontsize = 11

x = 'total_cond'
y = 'BL1-A_gmean'
hue = None
plottitle = ''

pairs = [
    ['False-retro', 'True-False'],
    ['True-False', 'True-retro']
]
yscale = 'log'
order = ['False-False', 'False-retro', 'True-False', 'True-retro']
palette = {'False-False':'grey', 'False-retro':'black', 'True-False':'#C3DB9A', 'True-retro':'#69B645'}
data_now = summary_well
hue_order = None


g = plt.figure(figsize=(xsize,ysize))
g = summary_plot( x=x, y=y, hue=hue, data=data_now, pairs=pairs, yscale=yscale, 
                     fontsize=fontsize,
                     x_rot=45, palette = palette, order=order, hue_order=hue_order, plottitle=plottitle, xlabel='', ylabel = 'Output gmean\n(mGL)', xticklabels=False)
g = g.get_figure()
#g.savefig(figure_folder+ 'mGL_gmean_summary_dox_cre_MEFS.svg',dpi=300,bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# False-retro v.s. True-False: t-test independent samples, P_val=3.133e-14 stat=-2.493e+01
# True-False v.s. True-retro: t-test independent samples, P_val=1.018e-10 stat=-1.472e+01

# %%
sns.set_context('paper')

# %%
font_sizes = {
    'annotation': 4,
    'base_size': 6,
    'subpanel_label': 10,
}

sns.set_style('ticks')
sns.set_context('paper', font_scale=1.0, rc={'font.size': font_sizes['base_size'], 'font.family': 'sans-serif', 'font.sans-serif':['Helvetica Neue']})
plt.rcParams.update({'axes.labelsize': font_sizes['base_size'], 'xtick.labelsize': font_sizes['base_size'], 'ytick.labelsize': font_sizes['base_size']})



subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
subdata = subdata.reset_index(drop=True)
colors = {False: '#C3DB9A', 'retro': '#69B645'}


fig, axs = plt.subplots(1, 1, figsize = (1, 0.5))

sns.kdeplot(data = subdata, x = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5, palette = colors, legend =False)

axs.set(xlim = (10, 5*10**5), xlabel = 'Output [mGL]')
no_dox = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
no_dox = no_dox.reset_index(drop=True)
sns.kdeplot(data = no_dox, x = 'BL1-A', color = 'black', ls = '--', lw = 1, log_scale = True, common_norm = False, fill = False, ax = axs, legend = False)

fig.set_facecolor('white')
sns.despine(fig)
fig.savefig(figure_folder + "lenti_ZF_MEFs_dox.svg", bbox_inches = 'tight')

# %%
font_sizes = {
    'annotation': 4,
    'base_size': 6,
    'subpanel_label': 10,
}

sns.set_style('ticks')
sns.set_context('paper', font_scale=1.0, rc={'font.size': font_sizes['base_size'], 'font.family': 'sans-serif', 'font.sans-serif':['Helvetica Neue']})
plt.rcParams.update({'axes.labelsize': font_sizes['base_size'], 'xtick.labelsize': font_sizes['base_size'], 'ytick.labelsize': font_sizes['base_size']})



subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > ZF43_retro_gate) &
               (data['YL2-A'] > 0)  ]
subdata = subdata.reset_index(drop=True)
colors = {False: '#C3DB9A', 'retro': '#69B645'}

#fig, axs = plt.subplots(1, 1, figsize = (1, 0.5))

sns.kdeplot(data = subdata, x = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, fill = True, alpha = 0.5, palette = colors, legend =False)

axs.set(xlim = (10, 5*10**5), xlabel = 'Output [mGL]')

fig.set_facecolor('white')
sns.despine(fig)
fig.savefig(figure_folder + "lenti_ZF_MEFs_cre.svg", bbox_inches = 'tight')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]

colors = {False: '#C3DB9A', 'retro': '#69B645'}


fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5, palette = colors)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-a2d6ec297c85> in <module>
#      17 fig, axs = plt.subplots(1, 1, figsize = (6, 6))
#      18
# ---> 19 sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5, palette = colors)
#      20
#      21 axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1781     else:
#    1782
# -> 1783         p.plot_bivariate_density(
#    1784             common_norm=common_norm,
#    1785             fill=fill,
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\seaborn\distributions.py in plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1084         densities, supports = {}, {}
#    1085
# -> 1086         for sub_vars, sub_data in self.iter_data("hue", from_comp_data=True):
#    1087
#    1088             # Extract the data points from this sub set and remove nulls
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\seaborn\_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\seaborn\_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
# -> 1732             self._setitem_single_block(indexer, value, name)
#    1733
#    1734     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\indexing.py in _setitem_single_block(self, indexer, value, name)
#    1957             # setting for extensionarrays that store dicts. Need to decide
#    1958             # if it's worth supporting that.
# -> 1959             value = self._align_series(indexer, Series(value))
#    1960
#    1961         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2094             # series, so need to broadcast (see GH5206)
#    2095             if sum_aligners == self.ndim and all(is_sequence(_) for _ in indexer):
# -> 2096                 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2097
#    2098                 # single indexer
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    4578     )
#    4579     def reindex(self, index=None, **kwargs):
# -> 4580         return super().reindex(index=index, **kwargs)
#    4581
#    4582     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4816
#    4817         # perform the reindex on the axes
# -> 4818         return self._reindex_axes(
#    4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4837
#    4838             axis = self._get_axis_number(a)
# -> 4839             obj = obj._reindex_with_indexers(
#    4840                 {axis: [new_index, indexer]},
#    4841                 fill_value=fill_value,
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881
#    4882             # TODO: speed up on homogeneous DataFrame objects
# -> 4883             new_data = new_data.reindex_indexer(
#    4884                 index,
#    4885                 indexer,
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# c:\Users\ChemeGrad2020\Dropbox (MIT)\MIT Graduate School\Galloway Lab\DIAL_git\newenv\lib\site-packages\pandas\core\indexes\base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([False]) ) &
               (data.Cre.isin([False])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]

colors = {False: '#C3DB9A', 'retro': '#69B645'}

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5, color ='grey')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 3*10**3) &
               (data['YL2-A'] > 0)  ]

colors = {False: '#C3DB9A', 'retro': '#69B645'}

fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5, palette = colors)

axs.set(xlim =  (10, 5*10**5), xlabel = 'Output [mGL]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 3*10**3) &
               (data['YL2-A'] > 0)  ]

fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (((data.ZF_delivery.isin(['lenti']) ) & (data.Dox.isin([True]) )) | ((data.ZF_delivery.isin(['retro']) ) & (data.Dox.isin([False]) ))) &
               (data.Cre.isin(['retro'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 3*10**3) &
               (data['YL2-A'] > 0)  ]

fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'ZF_delivery', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
subdata = data[(data.condition.isin(['mGreenLantern'])) &
               (data.promoter.isin(['divergent_203bp']) )&
               (data.marker.isin(['iRFP']) ) &
               (data.ZFa.isin(['ZF43']) ) &
               (data.ZF_delivery.isin(['lenti']) ) & 
               (data.Dox.isin([True]) ) &
               (data.Cre.isin([False, 'modRNA'])) &
               (data.CellTraceViolet.isin([False]) ) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > iRFP_gate) &
               (data['VL1-A'] > 3*10**3) &
               (data['YL2-A'] > 0)  ]

fig, axs = plt.subplots(1, 1, figsize = (6, 6))

sns.kdeplot(data = subdata, x = 'RL1-A', y = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set(xlim = (10**3, 10**6), ylim = (10, 5*10**5), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
data_loc1 = datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep1' /  'ctv_gates'
yaml_loc1 =  datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep1' / 'metadata.yaml'
data_loc2 = datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep2' /  'ctv_gates'
yaml_loc2 =  datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep2' / 'metadata.yaml'
data_loc3 = datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep3' /  'ctv_gates'
yaml_loc3 =  datadir/'instruments'/'data'/'attune'/'adam_attune'/ 'FC24_024.2024.06.17.DIAL_4dpi' / 'Rep3' / 'metadata.yaml'


# data pregated in flowjo to get diagonal gates for Cre excision. data alread ygated positive for ZF37-mCherry and marker gene (iRFP or mGL)

groups_df = pd.DataFrame(data = {'data_path': [data_loc1, data_loc2, data_loc3], 'yaml_path':[yaml_loc1, yaml_loc2, yaml_loc3]})

CTV_data = rd.flow.load_groups_with_metadata(groups_df, columns = ['BL1-A', 'RL1-A', 'YL2-A', 'VL1-A'])
CTV_data

# %%
subdata = CTV_data[(CTV_data.condition.isin(['Snap-p53DD'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['mGreenLantern']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]
subdata.well.value_counts()

fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'BL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel = 'mGreenLantern\n[marker gene expression]')


sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
subdata = CTV_data[(CTV_data.condition.isin(['Snap-p53DD'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['mGreenLantern']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]
subdata.well.value_counts()

fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'YL2-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel = 'mCherry\n[ZFa gene expression]')

sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

# %%
subdata = CTV_data[(CTV_data.condition.isin(['Snap-p53DD'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['mGreenLantern']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]
subdata.well.value_counts()

fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'RL1-A', hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5, legend = True)

axs.set( xlabel = 'Snap-p53DD\n[output gene expression]', ylim = (0, 1), xlim = (10, 3*10**5))

fig.set_facecolor('white')

snap_lig_data = data[(data.condition.isin(['Snap_lig'])) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]

sns.kdeplot(data = snap_lig_data, x = 'RL1-A', common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', linestyle = '--', legend = False)

# %%
subdata = CTV_data[(CTV_data.condition.isin(['Halo-p53'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['mGreenLantern']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]
subdata.well.value_counts()

fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'RL1-A',  hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel ='Halo-p53\n[output gene expression]', xlim = (5, 3*10**4))
# axs.set(xlim = (), ylim = (), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')


halo_lig_data = data[(data.condition.isin(['Halo-lig'])) &
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]

sns.kdeplot(data = halo_lig_data, x = 'RL1-A', common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', legend = False, ls = '--')

# %%
subdata = CTV_data[(CTV_data.condition.isin(['mGreenLantern'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['iRFP']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]
subdata.well.value_counts()

fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'BL1-A',  hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel ='mGreenLantern\n[output gene expression]')
# axs.set(xlim = (), ylim = (), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

ZF_only = data[(data.well.isin(['G9']))&
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
sns.kdeplot(data = ZF_only  , x = 'BL1-A',  hue = 'Cre', common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', legend = False, ls = '--')



# mGL_gate_output = 7*10**2
# axs.vlines(x = mGL_gate_output, ymin = 0, ymax = 1.2, color = 'black', linewidth  = 2 )

# %%
subdata = CTV_data[(CTV_data.condition.isin(['Halo-p53'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['mGreenLantern']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]


fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'VL1-A',  hue = 'population', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel ='CellTraceViolet')
# axs.set(xlim = (), ylim = (), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

CTV_only = data[(data.well.isin(['H9']))&
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
sns.kdeplot(data = CTV_only  , x = 'VL1-A',  common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', legend = False, ls = '--')

# %%
subdata = CTV_data[(CTV_data.condition.isin(['mGreenLantern'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['iRFP']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]


fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'VL1-A',  hue = 'population', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel ='CellTraceViolet')
# axs.set(xlim = (), ylim = (), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

CTV_only = data[(data.well.isin(['H9']))&
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
sns.kdeplot(data = CTV_only  , x = 'VL1-A',  common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', legend = False, ls = '--')

# %%
subdata = CTV_data[(CTV_data.condition.isin(['Snap-p53DD'])) &
               (CTV_data.promoter.isin(['divergent_203bp']) )&
               (CTV_data.marker.isin(['mGreenLantern']) ) &
               (CTV_data.ZFa.isin(['ZF37']) ) &
               (CTV_data.ZF_delivery.isin(['retro']) ) & 
               (CTV_data.Dox.isin([False]) ) &
               (CTV_data.Cre.isin([False, 'retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]


fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'VL1-A',  hue = 'population', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel ='CellTraceViolet')
# axs.set(xlim = (), ylim = (), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

CTV_only = data[(data.well.isin(['H9']))&
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
sns.kdeplot(data = CTV_only  , x = 'VL1-A',  common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', legend = False, ls = '--')

# %%
subdata = CTV_data[(CTV_data.Cre.isin([False])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]

fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'VL1-A',  hue = 'condition', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel ='CellTraceViolet')
# axs.set(xlim = (), ylim = (), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

CTV_only = data[(data.well.isin(['H9']))&
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
sns.kdeplot(data = CTV_only  , x = 'VL1-A',  common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', legend = False, ls = '--')

# %%
subdata = CTV_data[(CTV_data.Cre.isin(['retro'])) &
               (CTV_data.CellTraceViolet.isin([True]) ) &
               (CTV_data['BL1-A'] > 0) &
               (CTV_data['RL1-A'] > 0) &
               (CTV_data['VL1-A'] > 0) &
               (CTV_data['YL2-A'] > 0)  ]

fig, axs = plt.subplots(1, 1, figsize = (6, 3))

sns.kdeplot(data = subdata, x = 'VL1-A',  hue = 'condition', common_norm = False, log_scale=True, ax  =axs,  fill = True, alpha = 0.5)

axs.set( xlabel ='CellTraceViolet')
# axs.set(xlim = (), ylim = (), xlabel = 'iRFP-A\n [marker gene expression]', ylabel = 'mGreenLantern-A\n [output gene expression]')
sns.move_legend(axs, loc = 'upper left', bbox_to_anchor = (1, 1))

fig.set_facecolor('white')

CTV_only = data[(data.well.isin(['H9']))&
               (data['BL1-A'] > 0) &
               (data['RL1-A'] > 0) &
               (data['VL1-A'] > 0) &
               (data['YL2-A'] > 0)  ]
sns.kdeplot(data = CTV_only  , x = 'VL1-A',  common_norm = False, log_scale=True, ax  =axs,  fill = False, color = 'black', legend = False, ls = '--')
