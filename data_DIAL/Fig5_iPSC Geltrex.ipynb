# %% [markdown]
# Description

# %%
# data in iPSC transfection 
# 203-bp TET-DIAL was actually the 380-bp version, just was mislabeled in the yaml files, correctly labeled in the figure
# Fold change in the figure is the difference between means

# %% [markdown]
# # Import Functions and Data

# %% [markdown]
# ## Functions

# %%
import functions_paper_1
import importlib
from functions_paper_1 import *
exec(open("functions_paper_1.py").read())
# Local path to Sharepoint (on your computer, change if you are a different user)
datadir = Path(Path('../datadir_yb.txt').read_text())
datadir = Path(Path('../../datadir_srk.txt').read_text())
figure_folder = './figs_2024_promoter_editing_paper/fig5_iPSC/'

# %% [markdown]
# ## Import Data ##

# %%
# Import Data1
folder = '2024.06.14_EXP64'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'export_singlets' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata_new.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data1 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data1['bioreplicate'] = 'ELP1' 
data1['mCherry-A']=data1['mRuby2-A']

# %%
# Import Data2
folder = '2024.06.21_EXP67'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'export_singlets' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata.yaml' #Assign yaml paths 
rd.plot.plot_well_metadata(yaml_path)
data2 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data2['mCherry-A']=data2['mRuby2-A']

# %%
# Import Data2
folder = 'EXP124.1'

rep = 'rep_A'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/rep/'export_singlets_use' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data3 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data3['mCherry-A']=data3['mRuby2-A']
data3['bioreplicate'] = 'data3'

rep = 'rep_B'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/rep/'export_singlets_use' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data4 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data4['mCherry-A']=data4['mRuby2-A']
data4['bioreplicate'] = 'data4'

# %%
# Import Data 4-6
folder = 'EXP124.2'

rep = 'rep_1'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/rep/'export' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata_exp124.2.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data7 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data7['mCherry-A']=data3['mRuby2-A']
data7['bioreplicate'] = rep + '_' + folder

rep = 'rep_2'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/rep/'export' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata_exp124.2.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data5 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data5['mCherry-A']=data3['mRuby2-A']
data5['bioreplicate'] = rep + '_' + folder

rep = 'rep_3'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/rep/'export' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata_exp124.2.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data6 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data6['mCherry-A']=data3['mRuby2-A']
data6['bioreplicate'] = rep + '_' + folder

# %%
# Import Data 8, 9, 10
folder = 'EXP124.3'

rep = 'rep_1'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/rep/'export' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata_exp124.3.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data8 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data8['mCherry-A']=data3['mRuby2-A']
data8['bioreplicate'] = rep + '_' + folder

rep = 'rep_2'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/rep/'export' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata_exp124.3.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data9 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data9['mCherry-A']=data3['mRuby2-A']
data9['bioreplicate'] = rep + '_' + folder

rep = 'rep_3'
file_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/rep/'export' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Emma'/folder/'well_metadata_exp124.3.yaml' #Assign yaml paths 
#rd.plot.plot_well_metadata(yaml_path)
data10 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data10['mCherry-A']=data3['mRuby2-A']
data10['bioreplicate'] = rep + '_' + folder

# %%
data1.columns.unique()
data2.columns.unique()
# Out:
# Index(['Rept', 'ZF', 'Cre', 'VCre', 'DOX', 'bioreplicate', 'well',
#        'population', 'FSC-A', 'FSC-H', 'FSC-W', 'SSC-A', 'SSC-H', 'SSC-W',
#        'mGL-A', 'mGL-H', 'mGL-W', 'iRFP-A', 'iRFP-H', 'iRFP-W', 'tagBFP-A',
#        'tagBFP-H', 'tagBFP-W', 'YL1-A', 'YL1-H', 'YL1-W', 'mRuby2-A',
#        'mRuby2-H', 'mRuby2-W', 'Time', 'mCherry-A'],
#       dtype='object')

# %% [markdown]
# ### Concatanate and add conditions

# %%
data1 = data1[data1['Rept']!= 'loxPcontrol'] #used wrong plasmid in rep1 
data = pd.concat( [data1, data2, 
                   data3, data4, data5, data6, data7,
                   data8, data9, data10,
                   ], ignore_index=True, 
                   join='inner')

data = data[ data['mCherry-A'] >0]
data = data[ data['mGL-A'] >0]
#data = data[ data['tagBFP-A'] >0]
#data = data[ data['Janelia Fluor 549-A'] >0]
data = data[ data['iRFP-A'] >0]
data['log10 mGL-A'] = np.log10(data['mGL-A'])

#Add new condtion 
data['bioreplicate_reporter'] = data['bioreplicate'] + '_' + data['Rept']

#Add total condition 
data['cond_biorep'] = data['Rept'] + '.' + data['ZF'] + '.' + data['bioreplicate'] + '.' + data['Cre'] + '.' + data['VCre']
data['cond_full'] = data['Rept'] + '.' + data['ZF'] + '.'  + data['Cre']+ '.' + data['VCre']

# %%
#Combine ZF and Cre Conditions 
data['Rept.ZF.Cre'] = data['Rept'] + '.' +data['ZF'] + '.' + data['Cre']
data['Rept.DOX.Cre'] = data['Rept'] + '.' +data['DOX'] + '.' + data['Cre']
data['Rept.ZF.Cre.VCre'] = data['Rept'] + '.' +data['ZF'] + '.' + data['Cre']+ '.' + data['VCre']

# %%
#simplified cond list
data['cond'] = data['ZF'] + '. ' + data['Cre']
data['cond_VCre'] = data['ZF'] + '. ' + data['Cre'] + '. ' + data['VCre']

# %%
#Combine bioreplicate, ZF and Cre Conditions 
data['bioreplicate_cond_rept'] = data['bioreplicate'] + '. ' + data['Rept'] + '. ' + data['ZF'] + '. ' + data['Cre']

# %% [markdown]
# ### Gating

# %%
iRFP670_gate = 10000 
data_iRFP670gated = data[ data['iRFP-A'] > iRFP670_gate]

mCherry_gate = 1000
data_mCherrygated = data[ data['mCherry-A'] > mCherry_gate]

TagBFP_gate= 3000                         
data_TagBFPgated = data[ data['tagBFP-A']>TagBFP_gate]

data_mCherrygated=data_TagBFPgated #so that we dont have to change it throughout the code

# %% [markdown]
# ### cond_full list

# %%
display( pd.unique(data['cond_full'])   )
display( pd.unique(data_iRFP670gated['cond_full'])   )
display( pd.unique(data_mCherrygated['cond_full'])   )
# Out:
# array(['203bp.ZF37.noCre.noVCre', '203bp.noZF.noCre.noVCre',
#        '203bp.ZF37.Cre.noVCre', 'nested.ZF37.noCre.noVCre',
#        'nested.ZF37.Cre.noVCre', 'nested.ZF37.noCre.VCre',
#        '203bp-TET-DIAL.rtTA.noCre.noVCre', 'noRept.noZF.noCre.noVCre',
#        'NA.NA.NA.NA', '203bp-TET-DIAL.rtTA.Cre.noVCre',
#        'loxPcontrol.noZF.noCre.noVCre', 'loxPcontrol.ZF37.noCre.noVCre',
#        'loxPcontrol.ZF37.Cre.noVCre', 'nested.noZF.noCre.noVCre',
#        'nested.noZF.Cre.noVCre', 'tagBFPmarker.NA.NA.NA', 'none.NA.NA.NA',
#        'noRept.ZF37.noCre.noVCre'], dtype=object)
# array(['203bp.ZF37.noCre.noVCre', '203bp.noZF.noCre.noVCre',
#        '203bp.ZF37.Cre.noVCre', 'nested.ZF37.noCre.noVCre',
#        'nested.ZF37.Cre.noVCre', 'nested.ZF37.noCre.VCre',
#        '203bp-TET-DIAL.rtTA.noCre.noVCre', 'noRept.noZF.noCre.noVCre',
#        'NA.NA.NA.NA', '203bp-TET-DIAL.rtTA.Cre.noVCre',
#        'loxPcontrol.noZF.noCre.noVCre', 'loxPcontrol.ZF37.noCre.noVCre',
# ...

# %% [markdown]
# ### Simplified Cond list

# %%
# Make a list of all the cond. This will be used for the order later on 
cond_list = pd.unique( data_mCherrygated['cond_VCre'])
display(cond_list)
# Out:
# array(['ZF37. noCre. noVCre', 'noZF. noCre. noVCre', 'ZF37. Cre. noVCre',
#        'ZF37. noCre. VCre', 'rtTA. noCre. noVCre', 'NA. NA. NA',
#        'rtTA. Cre. noVCre', 'noZF. Cre. noVCre'], dtype=object)

# %%
cond_list_nounstained = pd.array([
    'noZF. noCre', 'noZF. Cre',
       'ZF37. noCre','ZF37. Cre', 'ZF37. noCre.noVCre', 'ZF37. VCre', 'ZF37. Cre.VCre' ] )

cond_list_noZF = pd.array([ 'noZF. noCre', 'noZF. Cre'] )
cond_list_ZF37 = pd.array([ 'ZF37. noCre', 'ZF37. Cre', 'ZF37. noCre.noVCre', 'ZF37. VCre', 'ZF37. Cre.VCre'] )

# %% [markdown]
# # Summary Plots ##

# %% [markdown]
# ## Calculate stats

# %%
df = data_TagBFPgated
#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre', 'bioreplicate'] #how to filter results, columns 
x = ['mGL-A', 'mCherry-A', 'tagBFP-A'] #which parameter to calculate results on
stat = [sp.stats.gmean, np.median, np.std, np.mean] #statistics to calculater
s = calc_stats(df,by,x,stat) #calculate statistics 
s['Normalize by tagBFP-A_gmean'] = s['mGL-A_gmean'] / s['tagBFP-A_gmean'] 
s['Normalize by tagBFP-A_median'] = s['mGL-A_median'] / s['tagBFP-A_median'] 
s['Normalize to ZFa_gmean'] = s['mGL-A_gmean'] / s['mCherry-A_gmean'] 
s['Normalize to ZFa_median'] = s['mGL-A_gmean'] / s['mCherry-A_median'] 
s['Normalize to noZFcond_nested'] = s['mGL-A_gmean'] / s[s['cond_full']=='nested.noZF.noCre.noVCre']['mGL-A_gmean'].mean()
s['Normalize to noVCre_cond_nested'] = s['mGL-A_gmean'] / s[s['cond_full']=='nested.ZF37.noCre.VCre']['mGL-A_gmean'].mean()
s['Normalize to ZFonly'] = s['mGL-A_median'] / s[s['cond_full']=='nested.ZF37.noCre.noVCre']['mGL-A_median'].mean()

# by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre', 'bioreplicate','well'] #how to filter results, columns 
# s_well =calc_stats(df,by,x,stat) #calculate statistics 
#dont use in the paper by well

# %%
# show = s[ s['Rept']=='203bp']
#          #,'nested','203bp-TET-DIAL'])])]
# display(show[['cond_full','bioreplicate','mGL-A_gmean','mGL-A_median']])

# # #display(s[s['Rept']=='nested'][['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre', 'bioreplicate']])
# # show = s[ s['Rept']=='203bp-TET-DIAL']
# # display(show[['Rept.DOX.Cre','bioreplicate','mGL-A_gmean','mGL-A_median']])

# show = s[ s['Rept']=='nested']
# display(show[['cond_full','bioreplicate','mGL-A_gmean','mGL-A_median']])

# # show = s_TETDIAL__gated_DOXmGLpos[ s_TETDIAL__gated_DOXmGLpos['Rept']=='203bp-TET-DIAL']
# # display(show[['Rept.DOX.Cre',,'bioreplicate','mGL-A_gmean','mGL-A_median']])

# %% [markdown]
# ## TET DIAL stats

# %%
# For TET-DIAL, DOX not turning on all transfected cells, gate mGL+
TagBFP_gate_TETDIAL = 3000
mGL_gate_TETDIAL = 2500
df = data
data_now = df
cond_list_TETDIAL_noDOX = pd.array( [ '203bp-TET-DIAL.noDOX.noCre',])
cond_list_TETDIAL_DOX = pd.array( [ '203bp-TET-DIAL.DOX.Cre','203bp-TET-DIAL.DOX.noCre'])
data_TETDIAL_noDOX = data_now[ data_now['Rept.DOX.Cre'].isin(cond_list_TETDIAL_noDOX) &
                                     (data['tagBFP-A']>TagBFP_gate_TETDIAL)]
data_TETDIAL_DOX = data_now[ (data_now['Rept.DOX.Cre'].isin(cond_list_TETDIAL_DOX)) 
                                    &
                                    (data_now['mGL-A']>mGL_gate_TETDIAL) & (data_now['tagBFP-A']>TagBFP_gate_TETDIAL)
                                    ]
data_TETDIAL_gated_DOXmGLpos = pd.concat([data_TETDIAL_noDOX,data_TETDIAL_DOX], ignore_index=True)

data_TETDIAL_gated_ALLmGLpos = data_TagBFPgated[(data_TagBFPgated['mGL-A']>2000)&(data['tagBFP-A']>TagBFP_gate_TETDIAL)] 


df = data_TETDIAL_gated_DOXmGLpos
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre', 'bioreplicate'] #how to filter results, columns 
x = ['mGL-A', 'mCherry-A', 'tagBFP-A'] #which parameter to calculate results on
stat = [sp.stats.gmean, np.median, np.std, np.mean] #statistics to calculater
s_TETDIAL = calc_stats(df,by,x,stat) #calculate statistics 
s_TETDIAL__gated_DOXmGLpos = s_TETDIAL

df = data_TETDIAL_gated_ALLmGLpos
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre', 'bioreplicate'] #how to filter results, columns 
x = ['mGL-A', 'mCherry-A', 'tagBFP-A'] #which parameter to calculate results on
stat = [sp.stats.gmean, np.median, np.std, np.mean] #statistics to calculater
s_TETDIAL = calc_stats(df,by,x,stat) #calculate statistics 
s_TETDIAL_gated_ALLmGLpos = s_TETDIAL
# Out:
# <ipython-input-171-2ce5f32bb192>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_TETDIAL_gated_ALLmGLpos = data_TagBFPgated[(data_TagBFPgated['mGL-A']>2000)&(data['tagBFP-A']>TagBFP_gate_TETDIAL)]

# %%
display(s[s['cond_full']=='nested.ZF37.noCre.VCre']['mGL-A_gmean'].mean())
display(s[s['cond_full']=='nested.ZF37.noCre.VCre']['Normalize to noVCre_cond_nested'].mean())
# Out:
# 1289.3246430579804
# 0.9999999999999999

# %% [markdown]
# ## means of means

# %%
# menas of means 

df = s
#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre'] #how to filter results, columns 
x = ['mGL-A_gmean', 'mCherry-A_gmean', 'tagBFP-A_gmean'] #which parameter to calculate results on
stat = [ np.mean] #statistics to calculater
s_meansofmeans = calc_stats(df,by,x,stat) #calculate statistics 

display(s_meansofmeans[s_meansofmeans['Count']>2][['cond_full','Count']])

# %% [markdown]
# ## Plot summary plots

# %% [markdown]
# ## stat label

# %%
# Make key for summary stats 

stat_label = { 'mGL-A_gmean': 'Output gmean (mGL)',
    'mCherry-A_gmean': 'Input ZFa gmean (mCherry)', 
    'tagBFP-A_gmean': 'Transfection control gmean (TagBFP)', 
    'Fold Change': 'Fold Change',
    'mGL-A_median': 'Output median (mGL)', 
    'Normalize by tagBFP-A_gmean': 'Output gmean (mGL) normalized by TagBFP marker', 
    'Normalize by tagBFP-A_median': 'Output median (mGL) normalized by TagBFP marker', 
   'Normalize to ZFa_gmean': 'Output gmean (mGL) normalized by ZFa', 
    'Normalize to ZFa_median': 'Output median (mGL) normalized by ZFa', 
    'Normalize to noZFcond_nested': 'Normalize to noZFcond_nested', 
    'Normalize to noVCre_cond_nested': 'Normalize to noVCre_cond_nested', 
    'Normalize to ZFonly': 'Normalize to ZFonly',
    'mGL normalized to tagBFP_median':'Output median (mGL) norm. by TagBFP marker SingleCell'
    }

# %% [markdown]
# ### 203bp plot

# %%
#Plot summary plot for the desired statistics

palette = {

            'noZF. noCre': 'grey',
           'ZF37. noCre': "#87C027",       #'#C3DB9A', 
           'ZF37. Cre': "#206002"}   # '#69B645'}


palette_mGL = {'noCre':"#87C027",       #'#C3DB9A', 
               'DNA_0.1xCre':'red', 
               'modRNA_100ngxCre': "#206002"}   # '#69B645'}

# 'noRept.noZF.noCre.noVCre'
hue_order = pd.array([
                     'noZF. noCre',
                     'noZF. Cre',
                      'ZF37. noCre',
                      'ZF37. Cre'
])


xsize =2; ysize = 2
fontsize=11

#List of stats to plot 
stats_plot = pd.array( ['mGL-A_gmean','mCherry-A_gmean', 'tagBFP-A_gmean'])
#set plotting parameters 
order_repts = pd.array( ['203bp']) #


#Only plot some reporters
data_now = s[s['Rept'].isin(order_repts)]
data_now = data_now[data_now['cond'].isin(hue_order)]
display(pd.unique(data_now['bioreplicate']))

order = palette; palette = palette; hue_order = None; x = 'cond'; hue=None; yscale= 'log'
x_pairs = 'cond'
ylim = [1e1, 8e3]

#Set p-value significance comparisons 
pairs = [
       ['ZF37. noCre', 'ZF37. Cre'], # +ZF43, -/+ Cre
       [ 'noZF. noCre','ZF37. noCre'], # +ZF43, -/+ Cre
]

for stat in stats_plot:
    y = stat # set the stat to plot
    plottitle = ''
    plt.figure(figsize=[xsize, ysize] )
    test = 't-test_ind'
    g = summary_plot( x=x, y=y, hue=hue, data=data_now, yscale =yscale, pairs=pairs, 
                    ylabel = stat_label[stat], xlabel='',  xticklabels=False,
                     x_rot=45, palette = palette, order=order, hue_order=hue_order, plottitle='',
                    fontsize=fontsize, 
                   test=test, stat_text="star"
                    )
    plottitle = stat + ' 203bp'
    g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')

data_now[['Rept', 'cond','cond_full','mGL-A_gmean','mCherry-A_gmean','tagBFP-A_gmean']].to_excel('Fig5_iPSC_203-bp_DIAL.xlsx',index=False)
# Out:
# array(['ELP1', 'Exp67-left', 'Exp67-right', 'data3', 'data4',
#        'rep_1_EXP124.2', 'rep_1_EXP124.3', 'rep_2_EXP124.2',
#        'rep_2_EXP124.3', 'rep_3_EXP124.2', 'rep_3_EXP124.3'], dtype=object)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ZF37. noCre v.s. ZF37. Cre: t-test independent samples, P_val=8.168e-04 stat=-3.936e+00
# noZF. noCre v.s. ZF37. noCre: t-test independent samples, P_val=5.382e-04 stat=-4.115e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ZF37. noCre v.s. ZF37. Cre: t-test independent samples, P_val=9.796e-01 stat=-2.590e-02
# noZF. noCre v.s. ZF37. noCre: t-test independent samples, P_val=1.385e-01 stat=-1.543e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# ...

# %% [markdown]
# #### fold change values based on means

# %%
# menas of means 
df = data_now
#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre'] #how to filter results, columns 
x = ['mGL-A_gmean'] #which parameter to calculate results on
stat = [ np.mean] #statistics to calculater
s_means_now = calc_stats(df,by,x,stat) #calculate statistics 

display('Fold Changes')
display(x_pairs)
for pair in pairs:
    value1 = s_means_now[s_means_now[x_pairs]==pair[0]]['mGL-A_gmean_mean'].iloc[0]
    value2 = s_means_now[s_means_now[x_pairs]==pair[1]]['mGL-A_gmean_mean'].iloc[0]
    display(pair)
    display(value2/value1)

display(s_means_now[['cond_full','Count']])
# Out:
# 'Fold Changes'
# 'cond'
# ['ZF37. noCre', 'ZF37. Cre']
# 4.092499217427454
# ['noZF. noCre', 'ZF37. noCre']
# 2.3327755291924284
#                  cond_full  Count
# 0    203bp.ZF37.Cre.noVCre     11
# 1  203bp.ZF37.noCre.noVCre     11
# 2  203bp.noZF.noCre.noVCre     11

# %% [markdown]
# #### 203bp fold change based on condtion with ZF37.noCre

# %%
# Develop map for the fold change by 
# by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre', 'bioreplicate'] #how to filter results, columns 
# x = ['mGL-A', 'tagBFP-A'] #which parameter to calculate results on
# stat = [sp.stats.gmean, np.median, np.std, np.mean] #statistics to calculater
# df = data_TagBFPgated[data_TagBFPgated['Rept']=='203bp']
# data_now = calc_stats(df,by,x,stat) #calculate statistics 
normalize_map_ZF37noCre = {'test': 'test'}
normalize_map_noZF = {'test': 'test'} 
normalize_map_noZF = {'test': 'test'} 
for bio in pd.unique( data_now['bioreplicate']):
       data_rep = data_now[ data_now['bioreplicate']==bio]
       #display(data_rep)
       normalize_map_ZF37noCre[bio] = data_rep[ data_rep['cond'] =='ZF37. noCre' ]['mGL-A_gmean'].iloc[0]
       normalize_map_noZF[bio] = data_rep[ data_rep['cond'] =='noZF. noCre' ]['mGL-A_gmean'].iloc[0]


#Calculate fold change plot, per bioreplicate 
data_now['ZF37. noCre'] = data_now['bioreplicate'].map(normalize_map_ZF37noCre)
data_now['Fold Change_ZF37. noCre'] = data_now['mGL-A_gmean'] / data_now['ZF37. noCre']
data_now['Fold Change_ZF37. noCre other way'] = data_now['ZF37. noCre']/data_now['mGL-A_gmean']
data_now['noZF. noCre'] = data_now['bioreplicate'].map(normalize_map_noZF)
data_now['Fold Change_noZF. noCre'] = data_now['mGL-A_gmean'] / data_now['noZF. noCre']

data_now[['Rept', 'cond','cond_full','cond_VCre','mGL-A_gmean','Fold Change_ZF37. noCre','Fold Change_ZF37. noCre other way','Fold Change_noZF. noCre']].to_excel('Fig5_iPSC_203bp_DIAL_foldchange.xlsx',index=False)

ys = pd.array(['Fold Change_ZF37. noCre','Fold Change_noZF. noCre','tagBFP-A_gmean'])
for y in ys: 
       y = y; stat=y # set the stat to plot
       x='cond';xsize =2; ysize = 2; fontsize=11
       plottitle = y+ '203bp'
       pairs = [
              ['ZF37. noCre', 'ZF37. Cre'], 
              ['ZF37. noCre', 'noZF. noCre'], 
       ]
       pairs =[]
       plt.figure(figsize=[xsize, ysize] )
       plt.axhline(y=1, ls='--', color='lightgray')
       g = summary_plot( x=x, y=y, hue=hue, data=data_now, yscale ='linear', pairs=pairs, 
                     x_rot=45, palette = palette, order=order, hue_order=hue_order, plottitle='', 
                     fontsize=fontsize, 
                     xlabel='',  xticklabels=False, 
                    # test='Kruskal'
                     )
       g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')

#Calculate average fold change per bio replicate
df = data_now
x = ['Fold Change_ZF37. noCre','Fold Change_noZF. noCre','Fold Change_ZF37. noCre other way']
stat = [np.mean]
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre']
data_foldchange = calc_stats(df,by,x,stat)
display(data_foldchange)

#Calculate fold change plot
data_now['ZF37. noCre'] = data_now['bioreplicate'].map(normalize_map_ZF37noCre)
data_now['Fold Change_ZF37. noCre'] = data_now['mGL-A_gmean'] / data_now['ZF37. noCre']
data_now['Fold Change_ZF37. noCre other way'] = data_now['ZF37. noCre']/data_now['mGL-A_gmean']
data_now['noZF. noCre'] = data_now['bioreplicate'].map(normalize_map_noZF)
data_now['Fold Change_noZF. noCre'] = data_now['mGL-A_gmean'] / data_now['noZF. noCre']

# data_now[['Rept', 'cond','cond_full','mGL-A_gmean','mCherry-A_gmean','tagBFP-A_gmean']].to_excel('Fig5_iPSC_203-bp_DIAL_foldchange_means.xlsx',index=False)
# Out:
#     Rept    ZF    Cre    VCre         cond            cond_VCre  \
# 0  203bp  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 1  203bp  ZF37  noCre  noVCre  ZF37. noCre  ZF37. noCre. noVCre
# 2  203bp  noZF  noCre  noVCre  noZF. noCre  noZF. noCre. noVCre
#
#                  cond_full    DOX       Rept.DOX.Cre  \
# 0    203bp.ZF37.Cre.noVCre  noDOX    203bp.noDOX.Cre
# 1  203bp.ZF37.noCre.noVCre  noDOX  203bp.noDOX.noCre
# 2  203bp.noZF.noCre.noVCre  noDOX  203bp.noDOX.noCre
#
#    Fold Change_ZF37. noCre_mean  Fold Change_noZF. noCre_mean  \
# 0                      3.859342                      9.846514
# 1                      1.000000                      2.439021
# 2                      0.510828                      1.000000
#
#    Fold Change_ZF37. noCre other way_mean  Fraction  Count
# 0                                0.292610       1.0     11
# 1                                1.000000       1.0     11
# 2                                2.439021       1.0     11

# %% [markdown]
# ### nested spacer summary plot

# %%
order_repts = pd.array( ['nested']) #
#Only plot some reporters
data_now = s[s['Rept'].isin(order_repts)]
display(data_now)
# Out:
#        Rept    ZF    Cre    VCre         cond            cond_VCre  \
# 81   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 82   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 83   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 84   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 85   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 86   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 87   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 88   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 89   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 90   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 91   nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 92   nested  ZF37  noCre    VCre  ZF37. noCre    ZF37. noCre. VCre
# 93   nested  ZF37  noCre    VCre  ZF37. noCre    ZF37. noCre. VCre
# ...

# %%
#Plot summary plot for the desired statistics

palette = {
        'noZF. noCre. noVCre': 'gray',
        #'noZF. Cre. noVCre': 'black',
           'ZF37. noCre. noVCre': "#87C027",       #'#C3DB9A', 
           'ZF37. noCre. VCre': "#306F13",  # '#69B645'}
           'ZF37. Cre. noVCre': "#112906"}   # '#69B645'}


palette_dark = {

            'noZF. noCre': 'grey',
           'ZF37. noCre': "#87C027",       #'#C3DB9A', 
           'ZF37. Cre': "#206002"}   # '#69B645'}

hue_order = palette


xsize =2; ysize = 2
fontsize=11



#List of stats to plot 
stats_plot = pd.array( [ 'mGL-A_gmean',
                        'mCherry-A_gmean', 'tagBFP-A_gmean'])
#set plotting parameters 
order_repts = pd.array( ['nested']) #
#Only plot some reporters
data_now = s[s['Rept'].isin(order_repts)]
data_now = data_now[data_now['cond_VCre'].isin(hue_order)]
data_now[data_now['bioreplicate']!= 'ELP1'] #missing the condition of noZF,noCre (adding leads to same results)
#display(data_now)


order = palette; palette = palette; hue_order = None; x = 'cond_VCre'; hue=None; yscale= 'log'
ylim = [1e1, 8e3]
x_pairs=x

pairs = [ 
       ['noZF. noCre. noVCre','ZF37. noCre. noVCre' ],
       ['ZF37. noCre. noVCre', 'ZF37. noCre. VCre'], 
       ['ZF37. noCre. VCre','ZF37. Cre. noVCre' ], 
       ['ZF37. noCre. noVCre','ZF37. Cre. noVCre' ]
]


for stat in stats_plot:
    y = stat # set the stat to plot
    plottitle = y+ 'nested'
    test = 't-test_ind'
    plt.figure(figsize=[xsize, ysize] )
    g = summary_plot( x=x, y=y, hue=hue, data=data_now, yscale =yscale, pairs=pairs,
                    ylabel = stat_label[stat], xlabel='',  xticklabels=False,
                    x_rot=45, palette = palette, order=order, hue_order=hue_order, plottitle='', 
                    fontsize=fontsize, 
                    test=test
                    )
    g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')

# menas of means 
df = data_now
#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre'] #how to filter results, columns 
x = ['mGL-A_gmean'] #which parameter to calculate results on
stat = [ np.mean] #statistics to calculater
s_means_now = calc_stats(df,by,x,stat) #calculate statistics 

display('Fold Changes')
display(x_pairs)
for pair in pairs:
    value1 = s_means_now[s_means_now[x_pairs]==pair[0]]['mGL-A_gmean_mean'].iloc[0]
    value2 = s_means_now[s_means_now[x_pairs]==pair[1]]['mGL-A_gmean_mean'].iloc[0]
    display(pair)
    display(value2/value1)
data_now[['Rept', 'cond','cond_full','cond_VCre','mGL-A_gmean','mCherry-A_gmean','tagBFP-A_gmean']].to_excel('Fig5_iPSC_nested_DIAL.xlsx',index=False)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# noZF. noCre. noVCre v.s. ZF37. noCre. noVCre: t-test independent samples, P_val=9.843e-06 stat=-5.957e+00
# ZF37. noCre. noVCre v.s. ZF37. noCre. VCre: t-test independent samples, P_val=1.460e-02 stat=-2.673e+00
# ZF37. noCre. VCre v.s. ZF37. Cre. noVCre: t-test independent samples, P_val=1.078e-02 stat=-2.811e+00
# ZF37. noCre. noVCre v.s. ZF37. Cre. noVCre: t-test independent samples, P_val=2.075e-03 stat=-3.536e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# noZF. noCre. noVCre v.s. ZF37. noCre. noVCre: t-test independent samples, P_val=1.671e-01 stat=-1.437e+00
# ZF37. noCre. noVCre v.s. ZF37. noCre. VCre: t-test independent samples, P_val=7.470e-01 stat=-3.270e-01
# ...

# %% [markdown]
# #### Fold change

# %%
#Calculate fold change plot, per bioreplicate 
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre', 'bioreplicate'] #how to filter results, columns 
x = ['mGL-A'] #which parameter to calculate results on
stat = [sp.stats.gmean, np.median, np.std, np.mean] #statistics to calculater
df = data_TagBFPgated[data_TagBFPgated['Rept']=='nested']
data_now = calc_stats(df,by,x,stat) #calculate statistics 
#data_now[data_now['bioreplicate']!= 'ELP1'] # missing the noZF, noCre condition 
normalize_map = {'test': 'test'}
normalize_map_medium = {'test': 'test'}
for bio in pd.unique( data_now['bioreplicate']):
       data_rep = data_now[ data_now['bioreplicate']==bio]
       #display(data_rep)
       data_rep_med = data_rep[ data_rep['cond_VCre'] =='ZF37. noCre. VCre' ]
       data_rep = data_rep[ data_rep['cond_VCre'] =='ZF37. noCre. noVCre' ]
       normalize_map[bio] = data_rep['mGL-A_gmean'].iloc[0]
       normalize_map_medium[bio] = data_rep_med['mGL-A_gmean'].iloc[0]
data_now['Normalize by mGL-A_gmean'] = data_now['bioreplicate'].map(normalize_map)
data_now['Normalize by mGL-A_gmean Med'] = data_now['bioreplicate'].map(normalize_map_medium)
data_now['Fold Change'] = data_now['mGL-A_gmean'] / data_now['Normalize by mGL-A_gmean']
data_now['Fold Change Medium'] = data_now['mGL-A_gmean'] / data_now['Normalize by mGL-A_gmean Med']


y = 'Fold Change'; stat=y # set the stat to plot
x='cond_VCre'
plottitle = y+ 'nested'
plt.figure(figsize=[xsize, ysize] )
plt.axhline(y=1, ls='--', color='lightgray')
#display(data_now)
g = summary_plot( x=x, y=y, hue=hue, data=data_now, yscale ='linear', pairs=[], 
              x_rot=45, palette = palette, order=order, hue_order=hue_order, plottitle='', 
              fontsize=fontsize, 
               xlabel='',  xticklabels=False)
g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')

y = 'Fold Change Medium'; stat=y # set the stat to plot
plottitle = y+ 'nested'
plt.figure(figsize=[xsize, ysize] )
plt.axhline(y=1, ls='--', color='lightgray')
g = summary_plot( x=x, y=y, hue=hue, data=data_now, yscale ='linear', pairs=[], 
              x_rot=45, palette = palette, order=order, hue_order=hue_order, plottitle='', 
              fontsize=fontsize, 
               xlabel='',  xticklabels=False)
g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')

data_now[['Rept', 'cond','cond_full','cond_VCre','mGL-A_gmean','Fold Change', 'Fold Change Medium']].to_excel('Fig5_iPSC_nested_DIAL_foldchange.xlsx',index=False)

#Calculate average fold change
df = data_now
x = ['Fold Change', 'Fold Change Medium']
stat = [np.mean]
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre']
data_foldchange = calc_stats(df,by,x,stat)
display(data_foldchange)
# Out:
#      Rept    ZF    Cre    VCre         cond            cond_VCre  \
# 0  nested  ZF37    Cre  noVCre    ZF37. Cre    ZF37. Cre. noVCre
# 1  nested  ZF37  noCre    VCre  ZF37. noCre    ZF37. noCre. VCre
# 2  nested  ZF37  noCre  noVCre  ZF37. noCre  ZF37. noCre. noVCre
# 3  nested  noZF    Cre  noVCre    noZF. Cre    noZF. Cre. noVCre
# 4  nested  noZF  noCre  noVCre  noZF. noCre  noZF. noCre. noVCre
#
#                   cond_full    DOX        Rept.DOX.Cre  Fold Change_mean  \
# 0    nested.ZF37.Cre.noVCre  noDOX    nested.noDOX.Cre          4.115108
# 1    nested.ZF37.noCre.VCre  noDOX  nested.noDOX.noCre          1.578099
# 2  nested.ZF37.noCre.noVCre  noDOX  nested.noDOX.noCre          1.000000
# 3    nested.noZF.Cre.noVCre  noDOX    nested.noDOX.Cre          0.637709
# 4  nested.noZF.noCre.noVCre  noDOX  nested.noDOX.noCre          0.509416
#
#    Fold Change Medium_mean  Fraction  Count
# 0                 2.511064       1.0     11
# 1                 1.000000       1.0     11
# ...

# %% [markdown]
# ### TET-DIAL

# %%
#Plot summary plot for the desired statistics

palette = {

            '203bp-TET-DIAL.noDOX.noCre': 'grey',
           '203bp-TET-DIAL.DOX.noCre': "#87C027",       #'#C3DB9A', 
           '203bp-TET-DIAL.DOX.Cre': "#206002"}   # '#69B645'}

hue_order = palette


xsize =2; ysize = 2
fontsize=11

#List of stats to plot 
stats_plot = pd.array( ['mGL-A_gmean','tagBFP-A_gmean'])
#set plotting parameters 
order_repts = pd.array( ['203bp-TET-DIAL']) #
#Only plot some reporters
s_now = s_TETDIAL__gated_DOXmGLpos
data_now = s_now[s_now['Rept'].isin(order_repts)]
data_now = data_now[data_now['Rept.DOX.Cre'].isin(hue_order)]
#data_now = data_now[~(data_now['bioreplicate'].isin(['rep_2_EXP124.3']))]

order = palette; palette = palette; hue_order = None; x = 'Rept.DOX.Cre'; hue=None; yscale= 'log'
x_pairs=x
ylim = [1e1, 8e3]


#Set p-value significance comparisons 
pairs =  [ 
       [('203bp-TET-DIAL','203bp-TET-DIAL.noDOX.noCre'),('203bp-TET-DIAL','203bp-TET-DIAL.DOX.noCre' )],
       [('203bp-TET-DIAL','203bp-TET-DIAL.DOX.noCre'), ('203bp-TET-DIAL','203bp-TET-DIAL.DOX.Cre')], 
]
pairs = [ 
       ['203bp-TET-DIAL.noDOX.noCre','203bp-TET-DIAL.DOX.noCre' ],
       ['203bp-TET-DIAL.DOX.noCre', '203bp-TET-DIAL.DOX.Cre'], 
]

for stat in stats_plot:
    y = stat # set the stat to plot
    plottitle = y+ 'TET-DIAL'
    plt.figure(figsize=[xsize, ysize] )
    test = 't-test_ind'
    g = summary_plot( x=x, y=y, hue=hue, data=data_now, yscale =yscale, pairs=pairs, 
                    x_rot=45, palette = palette, order=order, hue_order=hue_order, plottitle='', 
                    fontsize=fontsize, 
                    test=test,
                    ylabel = stat_label[stat], xlabel='',  xticklabels=False)
    g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')

data_now[['Rept', 'cond','cond_full','Rept.DOX.Cre','mGL-A_gmean','mCherry-A_gmean','tagBFP-A_gmean']].to_excel('Fig5_iPSC_380bp_TETDIAL.xlsx',index=False)

# menas of means 
df = data_now
#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre'] #how to filter results, columns 
x = ['mGL-A_gmean'] #which parameter to calculate results on
stat = [ np.mean] #statistics to calculater
s_means_now = calc_stats(df,by,x,stat) #calculate statistics 

display('Fold Changes')
display(x_pairs)
for pair in pairs:
    value1 = s_means_now[s_means_now[x_pairs]==pair[0]]['mGL-A_gmean_mean'].iloc[0]
    value2 = s_means_now[s_means_now[x_pairs]==pair[1]]['mGL-A_gmean_mean'].iloc[0]
    display(pair)
    display(value2/value1)
display(s_means_now[['Rept.DOX.Cre','Count']])
display(pd.unique(data_now['bioreplicate']))
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 203bp-TET-DIAL.noDOX.noCre v.s. 203bp-TET-DIAL.DOX.noCre: t-test independent samples, P_val=5.857e-09 stat=-9.638e+00
# 203bp-TET-DIAL.DOX.noCre v.s. 203bp-TET-DIAL.DOX.Cre: t-test independent samples, P_val=1.217e-02 stat=-2.757e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# 203bp-TET-DIAL.noDOX.noCre v.s. 203bp-TET-DIAL.DOX.noCre: t-test independent samples, P_val=9.480e-05 stat=-4.860e+00
# 203bp-TET-DIAL.DOX.noCre v.s. 203bp-TET-DIAL.DOX.Cre: t-test independent samples, P_val=8.183e-02 stat=1.832e+00
# 'Fold Changes'
# 'Rept.DOX.Cre'
# ['203bp-TET-DIAL.noDOX.noCre', '203bp-TET-DIAL.DOX.noCre']
# 27.23106812448295
# ['203bp-TET-DIAL.DOX.noCre', '203bp-TET-DIAL.DOX.Cre']
# ...

# %% [markdown]
# #### Fold change

# %%
# #Calculate fold change plot, per bioreplicate 
data_now = s_TETDIAL__gated_DOXmGLpos
normalize_map = {'test': 'test'}
for bio in pd.unique( data_now['bioreplicate']):
       data_rep = data_now[ data_now['bioreplicate']==bio]
       #display(data_rep)
       data_rep = data_rep[ data_rep['Rept.DOX.Cre'] =='203bp-TET-DIAL.DOX.noCre' ]
       normalize_map[bio] = data_rep['mGL-A_gmean'].iloc[0]
data_now['Normalize by mGL-A_gmean'] = data_now['bioreplicate'].map(normalize_map)
data_now['Fold Change'] = data_now['mGL-A_gmean'] / data_now['Normalize by mGL-A_gmean']
data_now[['Rept', 'cond','cond_full','Rept.DOX.Cre','mGL-A_gmean','Fold Change']].to_excel('Fig5_iPSC_380bp_TETDIAL_foldchanges.xlsx',index=False)


y = 'Fold Change'; stat=y # set the stat to plot
x='Rept.DOX.Cre'
plottitle = y+ 'TET-DIAL'
plt.figure(figsize=[xsize, ysize] )
plt.axhline(y=1, ls='--', color='lightgray')
g = summary_plot( x=x, y=y, hue=hue, data=data_now, yscale ='linear', pairs=[], 
              x_rot=45, palette = palette, order=order, hue_order=hue_order, plottitle=plottitle, 
              fontsize=fontsize, 
               xlabel='',  xticklabels=False)
g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')


#Calculate average fold change
df = data_now
x = ['Fold Change']
stat = [np.mean]
by = ['Rept', 'ZF', 'Cre', 'VCre', 'cond', 'cond_VCre','cond_full', 'DOX','Rept.DOX.Cre']
data_foldchange = calc_stats(df,by,x,stat)
display(data_foldchange)
# Out:
#              Rept    ZF    Cre    VCre         cond            cond_VCre  \
# 0  203bp-TET-DIAL  rtTA    Cre  noVCre    rtTA. Cre    rtTA. Cre. noVCre
# 1  203bp-TET-DIAL  rtTA  noCre  noVCre  rtTA. noCre  rtTA. noCre. noVCre
# 2  203bp-TET-DIAL  rtTA  noCre  noVCre  rtTA. noCre  rtTA. noCre. noVCre
#
#                           cond_full    DOX                Rept.DOX.Cre  \
# 0    203bp-TET-DIAL.rtTA.Cre.noVCre    DOX      203bp-TET-DIAL.DOX.Cre
# 1  203bp-TET-DIAL.rtTA.noCre.noVCre    DOX    203bp-TET-DIAL.DOX.noCre
# 2  203bp-TET-DIAL.rtTA.noCre.noVCre  noDOX  203bp-TET-DIAL.noDOX.noCre
#
#    Fold Change_mean  Fraction  Count
# 0          2.004409       1.0     11
# 1          1.000000       1.0     11
# 2          0.043169       1.0     11
