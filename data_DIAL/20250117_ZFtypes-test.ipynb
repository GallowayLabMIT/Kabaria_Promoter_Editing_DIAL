# %% [markdown]
# 20250117_ZFtypes-test

# %% [markdown]
# # Functions

# %%
import functions_paper_1
import importlib
from functions_paper_1 import *
exec(open("functions_paper_1.py").read())
# Local path to Sharepoint (on your computer, change if you are a different user)
datadir = Path(Path('../../datadir_srk.txt').read_text())
figure_folder = './figs_2024_promoter_editing_paper/20250117_ZFtypes-test/'

# %% [markdown]
# # Data

# %% [markdown]
# ## Import Data

# %%
# Import Data - bioreplicate 1
folder = '20250117_ZFtypes-test'
file_path = datadir/'instruments'/'data'/'attune'/'Sneha'/folder/'export_singlets' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Sneha'/folder/'well_metadata.yaml' #Assign yaml paths 
rd.plot.plot_well_metadata(yaml_path)
data1 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data1['bioreplicate'] = 'bio20250117'

# Import Data - bioreplicate 2
folder = '20250127_ZFtypes_twoplates'
file_path = datadir/'instruments'/'data'/'attune'/'Sneha'/folder/'p1_export_singlets' #Assign file paths
yaml_path = datadir/'instruments'/'data'/'attune'/'Sneha'/folder/'well_metadata.yaml' #Assign yaml paths 
rd.plot.plot_well_metadata(yaml_path)
data2 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data2['bioreplicate'] = 'bio20250127_p1'

# Import Data - bioreplicate 2
folder = '20250127_ZFtypes_twoplates'
file_path = datadir/'instruments'/'data'/'attune'/'Sneha'/folder/'p2_export_singlets' #Assign file paths
data3 = rd.flow.load_csv_with_metadata(file_path, yaml_path) #Pull data
data3['bioreplicate'] = 'bio20250127_p2'

# %% [markdown]
# ## Concatenate data, promoter assignment

# %%
data = pd.concat( [data1, data2, data3], ignore_index=True)
data = data[ data['mCherry-A'] >0]
data = data[ data['mGL-A'] >0]
data = data[ data['TagBFP-A'] >0]
data = data[ data['Janelia Fluor 549-A'] >0]
data = data[ data['iRFP670-A'] >0]

iRFPgate = 10000 
data_iRFP670gated = data[ (data['iRFP670-A']>iRFPgate) & (data['reporter']!='none') & (data['reporter']!='TET-AIO-mchHR')]
data_neg = data[ data['reporter']== 'none']

# %% [markdown]
# # Histograms

# %% [markdown]
# ## Palette

# %%
palette = { 'ZF': 'lightgray', 
           'ZF_Cre': 'black'}

# %% [markdown]
# ## Stacked histograms for mCherry and mGL

# %%
display( pd.unique(data_iRFP670gated['reporter']) )
display( pd.unique(data_iRFP670gated['ZF_Cre']) )
display( pd.unique(data_iRFP670gated['ZF_identity']) )
# Out:
# array(['pKG1525_pTET021_YB-TATA-mGL', 'pKG1525_pTET021_YB-TATA-mGL.none'],
#       dtype=object)
# array(['ZF_Cre', 'ZF', 'none'], dtype=object)
# array(['VPR-ZF37 addgene', 'noZF', 'VP16-ZF37-mCherry',
#        'VP16-ZF43-tagBFP', 'VP16-ZF37-tagBFP', 'CAG-VP16-ZF37-tagBFP',
#        'CAG-VPR-ZF37-tagBFP', 'CAG-VP16-ZF37-tagBFP_lenti',
#        'CAG-VPR-ZF37-tagBFP_lenti', '3223-VP16-ZF37-tagBFP',
#        '191B-CAG-VP16-ZF37-tagBFP', '192B-CAG-VPR-ZF37-tagBFP',
#        'CMV-VPR-ZF37 addgene', 'none'], dtype=object)

# %%
#Create conditions dictionary

hue = 'ZF_Cre'


conditions = {}
for ZF_identity in pd.unique(data_iRFP670gated['ZF_identity']):
    conditions[ZF_identity] = 'ZF_identity'

for channel in pd.array( ['mGL-A', 'mCherry-A', 'TagBFP-A']):
    data_now_now = data_iRFP670gated
    plottitle = ''
    h = custom_hist_plot_stacked( data_now_now, 
                        parameters=pd.array([channel]), hue=hue, palette=palette, hueorder=palette, title=plottitle, 
                        alpha=0.01, fontsize=18, data_neg= data_neg, conditions=conditions,
                        legendtitle='Condition',  xlim = [1e0, 1e6], xl = 'Output (mCherry)', ysize = 2, xsize = 6,
                        axis_lines={'top': False, 'bottom': True, 'left': False, 'right': False},legend=True)
    h = h.get_figure()
    plottitle = 'hist.all.'+channel
    h.savefig(figure_folder+ plottitle + '.svg',dpi=300,bbox_inches='tight')
# Out:
# 0
# VPR-ZF37 addgene
# unstained should show
# 1
# noZF
# unstained should show
# 2
# VP16-ZF37-mCherry
# unstained should show
# 3
# VP16-ZF43-tagBFP
# unstained should show
# 4
# VP16-ZF37-tagBFP
# unstained should show
# 5
# CAG-VP16-ZF37-tagBFP
# unstained should show
# 6
# CAG-VPR-ZF37-tagBFP
# unstained should show
# 7
# CAG-VP16-ZF37-tagBFP_lenti
# unstained should show
# 8
# CAG-VPR-ZF37-tagBFP_lenti
# unstained should show
# 9
# 3223-VP16-ZF37-tagBFP
# unstained should show
# 10
# 191B-CAG-VP16-ZF37-tagBFP
# unstained should show
# 11
# 192B-CAG-VPR-ZF37-tagBFP
# unstained should show
# 12
# CMV-VPR-ZF37 addgene
# unstained should show
# 13
# none
# unstained should show
# 0
# VPR-ZF37 addgene
# unstained should show
# 1
# noZF
# unstained should show
# 2
# VP16-ZF37-mCherry
# unstained should show
# 3
# VP16-ZF43-tagBFP
# unstained should show
# 4
# VP16-ZF37-tagBFP
# unstained should show
# 5
# CAG-VP16-ZF37-tagBFP
# unstained should show
# 6
# CAG-VPR-ZF37-tagBFP
# unstained should show
# 7
# CAG-VP16-ZF37-tagBFP_lenti
# unstained should show
# 8
# CAG-VPR-ZF37-tagBFP_lenti
# unstained should show
# 9
# 3223-VP16-ZF37-tagBFP
# unstained should show
# 10
# 191B-CAG-VP16-ZF37-tagBFP
# unstained should show
# 11
# 192B-CAG-VPR-ZF37-tagBFP
# unstained should show
# 12
# CMV-VPR-ZF37 addgene
# unstained should show
# 13
# none
# unstained should show
# 0
# VPR-ZF37 addgene
# unstained should show
# 1
# noZF
# unstained should show
# 2
# VP16-ZF37-mCherry
# unstained should show
# 3
# VP16-ZF43-tagBFP
# unstained should show
# 4
# VP16-ZF37-tagBFP
# unstained should show
# 5
# CAG-VP16-ZF37-tagBFP
# unstained should show
# 6
# CAG-VPR-ZF37-tagBFP
# unstained should show
# 7
# CAG-VP16-ZF37-tagBFP_lenti
# unstained should show
# 8
# CAG-VPR-ZF37-tagBFP_lenti
# unstained should show
# 9
# 3223-VP16-ZF37-tagBFP
# unstained should show
# 10
# 191B-CAG-VP16-ZF37-tagBFP
# unstained should show
# 11
# 192B-CAG-VPR-ZF37-tagBFP
# unstained should show
# 12
# CMV-VPR-ZF37 addgene
# unstained should show
# 13
# none
# unstained should show

# %% [markdown]
# # Joint Plots

# %%
display( pd.unique(data_iRFP670gated['ZF_identity']))
# Out:
# array(['VPR-ZF37 addgene', 'noZF', 'VP16-ZF37-mCherry',
#        'VP16-ZF43-tagBFP', 'VP16-ZF37-tagBFP', 'CAG-VP16-ZF37-tagBFP',
#        'CAG-VPR-ZF37-tagBFP', 'CAG-VP16-ZF37-tagBFP_lenti',
#        'CAG-VPR-ZF37-tagBFP_lenti', '3223-VP16-ZF37-tagBFP',
#        '191B-CAG-VP16-ZF37-tagBFP', '192B-CAG-VPR-ZF37-tagBFP',
#        'CMV-VPR-ZF37 addgene', 'none'], dtype=object)

# %%
#Create conditions dictionary

palette = { 'ZF': 'red', 
           'ZF_Cre': 'blue', 
           'none': 'gray'}

hue = 'ZF_Cre'

ZF_list = pd.array(['VPR-ZF37 addgene', 
        'VP16-ZF37-tagBFP', 'CAG-VP16-ZF37-tagBFP',
       'CAG-VPR-ZF37-tagBFP', '3223-VP16-ZF37-tagBFP',
       '191B-CAG-VP16-ZF37-tagBFP', '192B-CAG-VPR-ZF37-tagBFP',
       'CMV-VPR-ZF37 addgene'], dtype=object)

for bio in pd.unique( data_iRFP670gated['bioreplicate']):
    data_now = data_iRFP670gated[ data_iRFP670gated['bioreplicate']==bio]
    for ZF in pd.unique( data_now['ZF_identity']):
        if ZF in ZF_list:
            data_now_now = data_now[ data_now['ZF_identity']==ZF]
            plottitle = bio+ '.' + ZF
            display(plottitle )
            h= custom_density_plot(xcat='mGL-A',ycat='TagBFP-A',hue=hue,data=data_now_now,points = 10000, hue_order=None,
                                    savetitle='',plottitle=plottitle,palette=palette,xlim=(0.5*10**0, 1*10**6),ylim = (0.5*10**0, 1*10**6),
                                    type=['contour'],alpha=0.2, legend=True,
                                    hline=False,              # Horizontal line to be added to the plot (float)
                                    vline=False,               # Vertical line to be added to the plot (float)
                                    sample=True
                                    )
            h.savefig(figure_folder+ plottitle + '.svg',dpi=300,bbox_inches='tight')
# Out:
# 'bio20250117.VPR-ZF37 addgene'
# 4658
# 'bio20250117.VP16-ZF37-tagBFP'
# 10000
# 'bio20250117.CAG-VP16-ZF37-tagBFP'
# 10000
# 'bio20250117.CAG-VPR-ZF37-tagBFP'
# 3239
# 'bio20250127_p1.3223-VP16-ZF37-tagBFP'
# 10000
# 'bio20250127_p1.191B-CAG-VP16-ZF37-tagBFP'
# 10000
# 'bio20250127_p1.192B-CAG-VPR-ZF37-tagBFP'
# 5103
# 'bio20250127_p1.CMV-VPR-ZF37 addgene'
# 2440
# 'bio20250127_p2.3223-VP16-ZF37-tagBFP'
# 5105
# 'bio20250127_p2.191B-CAG-VP16-ZF37-tagBFP'
# 5069
# 'bio20250127_p2.192B-CAG-VPR-ZF37-tagBFP'
# 4153
# 'bio20250127_p2.CMV-VPR-ZF37 addgene'
# 3240

# %% [markdown]
# # Summary Stats Calculations

# %%
df = data_iRFP670gated

#Decide how to group. The last parameter will be the condition that it is group by by last ('well' or 'bioreplicate')
by = ['reporter', 'ZF_Cre', 'bioreplicate', 'well'] #how to filter results, columns 
x = ['mGL-A', 'TagBFP-A', 'mCherry-A'] #which parameter to calculate results on
stat = [sp.stats.gmean, np.median, np.std, np.mean] #statistics to calculate
s = calc_stats(df,by,x,stat) #calculate statistics

# %% [markdown]
# # Fold Change Calculation

# %%
# normalize all to the +DOX, -GIB conditon with the 203bp spacer

s_repts = s[ s['reporter'] != 'none']
bios = pd.unique(s_repts['bioreplicate'] )
repts = pd.unique(s_repts['reporter'] )

map = {'test':'test'}

for biorep in bios:
    for rept in repts:
        # Normalize all to the noCre ZF37 conditions
        mGL_noCre_ZF37 =  s_repts[ s_repts['ZF_Cre']=='ZF37']
        mGL_noCre_ZF37 =  mGL_noCre_ZF37[ mGL_noCre_ZF37['bioreplicate']==biorep]
        mGL_noCre_ZF37 =  mGL_noCre_ZF37[ mGL_noCre_ZF37['reporter']==rept]
        mGL_noCre_ZF37= mGL_noCre_ZF37['mGL-A_gmean'].iloc[0]
        map[biorep + rept] = mGL_noCre_ZF37
#display(map)

s['map'] = s['bioreplicate'] + s['reporter']
s['ZF'] = s['map'].map(map)
s['Fold Change'] = s['mGL-A_gmean'] / s['ZF']

df = s
by = ['reporter', 'promoter', 'ZF_Cre' ] #how to filter results, columns 
x = ['Fold Change','mGL-A_gmean', 'TagBFP-A_gmean', 'mCherry-A_gmean' ] #which parameter to calculate results on
stat = [np.mean] #statistics to calculate
s_fold = calc_stats(df,by,x,stat) #calculate statistics 
display(s_fold[s_fold['ZF_Cre']=='ZF37_Cre'])
# Out:
#                    reporter   promoter    ZF_Cre  Fold Change_mean  \
# 2   pKG1525_pTET021_YB-TATA    YB_TATA  ZF37_Cre          8.687033
# 6            pTET161_minCMV     minCMV  ZF37_Cre          6.242537
# 10             pTET176_SV40       SV40  ZF37_Cre          1.655020
# 14        pTET177_minCMV-YC    minCMV2  ZF37_Cre          3.089527
# 18               pTET178_JB  pJB42CAT5  ZF37_Cre          6.948742
# 22              pTET179_MLP        MLP  ZF37_Cre          8.199973
# 26            pTET180_CMV53      CMV53  ZF37_Cre          2.231633
#
#     mGL-A_gmean_mean  TagBFP-A_gmean_mean  mCherry-A_gmean_mean  Fraction  \
# 2        3517.731541           724.125846             47.347007      0.25
# 6       18059.960035          1469.618974             47.057893      0.25
# 10       6700.309205          1035.707681             46.724436      0.25
# 14      18225.024522           873.581996             45.512239      0.25
# 18       2874.543319           980.414209             46.719806      0.25
# 22       2922.717387           717.346066             47.104367      0.25
# 26      37992.589310           601.111409             43.472648      0.25
#
#     Count
# 2       4
# 6       4
# 10      4
# 14      4
# 18      4
# 22      4
# 26      4

# %% [markdown]
# # Summary Plots

# %%
pairs = []
for i in range(len(pd.unique(s['reporter']))):
    rept = pd.unique(s['reporter'])[i]
    if i == 0:
      pairs = [[(rept, 'ZF37'), (rept, 'ZF37_Cre')]]
    else:
      pairs = pairs + [[(rept, 'ZF37'), (rept, 'ZF37_Cre')]]

# %%
x = 'reporter'; x_rot = 45
xlabel = ''
xsize =6  ; ysize = 3
fontsize = 14
 
yscales = pd.array(['log'])
ylim = [0,10]
pairs = pairs
palette = {'none': '#a4a6a3',
               'Flp': '#7b7d7a', 
   'Cre': '#3d3e3d', 
   'Cre_Flp': '#000000',
     'ZF37': '#ff7d7d',                                                
      'ZF37_Flp': '#b64e4e', 
      'ZF37_Cre':'#960202',
      'ZF37_Cre_Flp':'#3c0101'}
hue = 'ZF_Cre';  hueorder = palette;
order =  pd.unique(data_iRFP670gated['reporter'])
data_now = s

y = 'mCherry-A_gmean'
ylabel = 'Output gmean (mCherry)'
yscale = 'log'
ylim = [3e1, 5e4]
plottitle = y
g = plt.figure(figsize=(xsize,ysize))
g = summary_plot( x, y, hue, data=data_now, dodge=True, palette = palette, order=order, 
                hue_order = hueorder, plottitle='',yscale=yscale,x_rot = x_rot,
                ylim =ylim, fontsize=fontsize, ylabel=ylabel, xticklabels=True, xlabel=xlabel,
                pairs=pairs, legend=False)
g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')


y = 'mGL-A_gmean'
ylabel = 'Output gmean (mGL)'
yscale = 'log'
ylim = [3e1, 5e4]
plottitle = y
g = plt.figure(figsize=(xsize,ysize))
g = summary_plot( x, y, hue, data=data_now, dodge=True, palette = palette, order=order, 
                hue_order = hueorder, plottitle='',yscale=yscale,x_rot = x_rot,
                ylim =ylim, fontsize=fontsize, ylabel=ylabel, xticklabels=True, xlabel=xlabel,
                pairs=pairs, legend=False)
g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')


y = 'TagBFP-A_gmean'
ylabel = 'Input gmean (VP16-ZF37)'
yscale = 'log'
ylim = [3e1, 5e4]
plottitle = y
g = plt.figure(figsize=(xsize,ysize))
g = summary_plot( x, y, hue, data=data_now, dodge=True, palette = palette, order=order, 
                hue_order = hueorder, plottitle='',yscale=yscale,x_rot = x_rot,
                ylim =ylim, fontsize=fontsize, ylabel=ylabel, xticklabels=True, xlabel=xlabel,
                pairs=pairs, legend=False)
g.figure.savefig(figure_folder + plottitle + '.svg',dpi=300,bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# pTET204_830bp_Brn2-mCh_ZF37 v.s. pTET204_830bp_Brn2-mCh_ZF37_Cre: t-test independent samples, P_val=3.586e-05 stat=-2.014e+01
# pTET197_570bp_Brn2-mCh_ZF37 v.s. pTET197_570bp_Brn2-mCh_ZF37_Cre: t-test independent samples, P_val=9.602e-04 stat=-8.702e+00
# pTET201_570bp_mGL_ZF37 v.s. pTET201_570bp_mGL_ZF37_Cre: t-test independent samples, P_val=8.813e-01 stat=1.591e-01
# pTET202_570bp_mCh_ZF37 v.s. pTET202_570bp_mCh_ZF37_Cre: t-test independent samples, P_val=1.246e-02 stat=-4.319e+00
# pTET203_570bp_mCh-HR_ZF37 v.s. pTET203_570bp_mCh-HR_ZF37_Cre: t-test independent samples, P_val=1.561e-01 stat=1.744e+00
# pTET205_830bp_mGL_ZF37 v.s. pTET205_830bp_mGL_ZF37_Cre: t-test independent samples, P_val=2.508e-01 stat=-1.342e+00
# pTET206_830bp_mCh_ZF37 v.s. pTET206_830bp_mCh_ZF37_Cre: t-test independent samples, P_val=2.833e-03 stat=-6.535e+00
# pTET207_830bp_mCh-HR_ZF37 v.s. pTET207_830bp_mCh-HR_ZF37_Cre: t-test independent samples, P_val=6.799e-05 stat=-1.714e+01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# pTET204_830bp_Brn2-mCh_ZF37 v.s. pTET204_830bp_Brn2-mCh_ZF37_Cre: t-test independent samples, P_val=2.585e-01 stat=1.316e+00
# pTET197_570bp_Brn2-mCh_ZF37 v.s. pTET197_570bp_Brn2-mCh_ZF37_Cre: t-test independent samples, P_val=1.576e-01 stat=-1.736e+00
# pTET201_570bp_mGL_ZF37 v.s. pTET201_570bp_mGL_ZF37_Cre: t-test independent samples, P_val=1.616e-03 stat=-7.590e+00
# pTET202_570bp_mCh_ZF37 v.s. pTET202_570bp_mCh_ZF37_Cre: t-test independent samples, P_val=9.150e-01 stat=-1.136e-01
# pTET203_570bp_mCh-HR_ZF37 v.s. pTET203_570bp_mCh-HR_ZF37_Cre: t-test independent samples, P_val=1.174e-01 stat=-1.990e+00
# pTET205_830bp_mGL_ZF37 v.s. pTET205_830bp_mGL_ZF37_Cre: t-test independent samples, P_val=3.754e-06 stat=-3.551e+01
# pTET206_830bp_mCh_ZF37 v.s. pTET206_830bp_mCh_ZF37_Cre: t-test independent samples, P_val=5.769e-02 stat=-2.638e+00
# pTET207_830bp_mCh-HR_ZF37 v.s. pTET207_830bp_mCh-HR_ZF37_Cre: t-test independent samples, P_val=1.051e-02 stat=-4.539e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# pTET204_830bp_Brn2-mCh_ZF37 v.s. pTET204_830bp_Brn2-mCh_ZF37_Cre: t-test independent samples, P_val=4.036e-02 stat=2.989e+00
# pTET197_570bp_Brn2-mCh_ZF37 v.s. pTET197_570bp_Brn2-mCh_ZF37_Cre: t-test independent samples, P_val=7.608e-02 stat=2.379e+00
# pTET201_570bp_mGL_ZF37 v.s. pTET201_570bp_mGL_ZF37_Cre: t-test independent samples, P_val=2.139e-01 stat=1.476e+00
# pTET202_570bp_mCh_ZF37 v.s. pTET202_570bp_mCh_ZF37_Cre: t-test independent samples, P_val=8.039e-03 stat=-4.901e+00
# pTET203_570bp_mCh-HR_ZF37 v.s. pTET203_570bp_mCh-HR_ZF37_Cre: t-test independent samples, P_val=2.513e-01 stat=1.340e+00
# pTET205_830bp_mGL_ZF37 v.s. pTET205_830bp_mGL_ZF37_Cre: t-test independent samples, P_val=1.912e-03 stat=7.260e+00
# pTET206_830bp_mCh_ZF37 v.s. pTET206_830bp_mCh_ZF37_Cre: t-test independent samples, P_val=9.019e-03 stat=4.743e+00
# pTET207_830bp_mCh-HR_ZF37 v.s. pTET207_830bp_mCh-HR_ZF37_Cre: t-test independent samples, P_val=3.274e-02 stat=3.205e+00
